# %%
import pandas as pd 
import matplotlib.pyplot as plt

# specify the encoding
Newdata=pd.read_csv('Instagram dataSet.csv', encoding='latin1')

# %%
Newdata.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
Newdata.tail()
# Out:
#      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
#      Comments  Shares  Likes  Profile Visits  Follows  \
# 114         2      38    373              73       80
# 115         4       1    148              20       18
# 116         0       1     92              34       10
# 117         2      75    549             148      214
# 118         5      26    443             611      228
#
#                                                Caption  \
# 114  Here are some of the best data science certifi...
# 115  Clustering is a machine learning technique use...
# ...

# %%
Newdata.describe()
# Out:
#         Impressions     From Home  From Hashtags  From Explore   From Other  \
# count    119.000000    119.000000     119.000000    119.000000   119.000000
# mean    5703.991597   2475.789916    1887.512605   1078.100840   171.092437
# std     4843.780105   1489.386348    1884.361443   2613.026132   289.431031
# min     1941.000000   1133.000000     116.000000      0.000000     9.000000
# 25%     3467.000000   1945.000000     726.000000    157.500000    38.000000
# 50%     4289.000000   2207.000000    1278.000000    326.000000    74.000000
# 75%     6138.000000   2602.500000    2363.500000    689.500000   196.000000
# max    36919.000000  13473.000000   11817.000000  17414.000000  2547.000000
#
#              Saves    Comments      Shares       Likes  Profile Visits  \
# count   119.000000  119.000000  119.000000  119.000000      119.000000
# mean    153.310924    6.663866    9.361345  173.781513       50.621849
# ...

# %%
Newdata.shape
# Out:
# (119, 13)

# %%
Newdata.columns
# Out:
# Index(['Impressions', 'From Home', 'From Hashtags', 'From Explore',
#        'From Other', 'Saves', 'Comments', 'Shares', 'Likes', 'Profile Visits',
#        'Follows', 'Caption', 'Hashtags'],
#       dtype='object')

# %%
print(Newdata['Impressions'].value_counts())
# Out:
# Impressions
# 5394     3
# 3169     2
# 7407     2
# 4082     2
# 2407     2
#         ..
# 2191     1
# 3990     1
# 2327     1
# 2523     1
# 36919    1
# Name: count, Length: 101, dtype: int64

# %%
Newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Impressions     119 non-null    int64
#  1   From Home       119 non-null    int64
#  2   From Hashtags   119 non-null    int64
#  3   From Explore    119 non-null    int64
#  4   From Other      119 non-null    int64
#  5   Saves           119 non-null    int64
#  6   Comments        119 non-null    int64
#  7   Shares          119 non-null    int64
#  8   Likes           119 non-null    int64
#  9   Profile Visits  119 non-null    int64
#  10  Follows         119 non-null    int64
#  11  Caption         119 non-null    object
#  12  Hashtags        119 non-null    object
# dtypes: int64(11), object(2)
# memory usage: 12.2+ KB

# %%
specific_columns=[["Impressions", "From Home"]]
print(specific_columns)
# Out:
# [['Impressions', 'From Home']]

# %%
Newdata['New_column']=Newdata ['Shares']+Newdata['Likes']

# %%
Newdata.head
# Out:
# <bound method NDFrame.head of      Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0           3920       2586           1028           619          56     98
# 1           5394       2727           1838          1174          78    194
# 2           4021       2085           1188             0         533     41
# 3           4528       2700            621           932          73    172
# 4           2518       1704            255           279          37     96
# ..           ...        ...            ...           ...         ...    ...
# 114        13700       5185           3041          5352          77    573
# 115         5731       1923           1368          2266          65    135
# 116         4139       1133           1538          1367          33     36
# 117        32695      11815           3147         17414         170   1095
# 118        36919      13473           4176         16444        2547    653
#
# ...

# %%
Newdata.rename(columns={ 'feedback': 'replies'}, inplace=True)

# %%
Newdata.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  Follows  \
# 0         9       5    162              35        2
# 1         7      14    224              48       10
# 2        11       1    131              62       12
# 3        10       7    213              23        8
# 4         5       4    123               8        0
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# ...

# %%
Newdata.drop(columns=['Follows'], inplace=True)

# %%
Newdata.head()
# Out:
#    Impressions  From Home  From Hashtags  From Explore  From Other  Saves  \
# 0         3920       2586           1028           619          56     98
# 1         5394       2727           1838          1174          78    194
# 2         4021       2085           1188             0         533     41
# 3         4528       2700            621           932          73    172
# 4         2518       1704            255           279          37     96
#
#    Comments  Shares  Likes  Profile Visits  \
# 0         9       5    162              35
# 1         7      14    224              48
# 2        11       1    131              62
# 3        10       7    213              23
# 4         5       4    123               8
#
#                                              Caption  \
# 0  Here are some of the most important data visua...
# 1  Here are some of the best data science project...
# 2  Learn how to train a machine learning model an...
# ...

# %%
Newdata.to_csv('Revisced Data.csv', index=False)

# %%
plt.hist(Newdata["From Home"], bins=5, edgecolor='black')
plt.title("From Home")
plt.xlabel('value: from hashtags')
plt.ylabel('freauency: likes')
plt.show()

# %%
plt.boxplot(Newdata['Profile Visits'])
plt.title("Boxplot of Dataset")
plt.show(0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
mydata=np.random.rand(10,12)
Coorelation_matrix=np.corrcoef (mydata)
plt.figure(figsize=(10,8))
sns.heatmap(Coorelation_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x='Likes',y='Shares',data=Newdata)#Palette='muted')
plt.title('Violin PLot of Impressions across Shares')
plt.show()

# %%
import seaborn as sns
titanic=sns.load_dataset("titanic")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# -> 1382 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...
